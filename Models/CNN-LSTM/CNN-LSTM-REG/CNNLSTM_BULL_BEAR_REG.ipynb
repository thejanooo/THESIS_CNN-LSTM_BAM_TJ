# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Flatten, Conv2D, MaxPooling2D, Reshape
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.callbacks import EarlyStopping
from keras_tuner import RandomSearch
from keras.optimizers import Adam
import random

# Define the file paths for each period
file_paths = {
    'bear_market_1': '/Users/thomas/Documents/GitHub/CNN-LSTM/Models_v2/Final_df/bear_market_1_regression.csv',
    'bear_market_2': '/Users/thomas/Documents/GitHub/CNN-LSTM/Models_v2/Final_df/bear_market_2_regression.csv',
    'bull_market_1': '/Users/thomas/Documents/GitHub/CNN-LSTM/Models_v2/Final_df/bull_market_1_regression.csv',
    'bull_market_2': '/Users/thomas/Documents/GitHub/CNN-LSTM/Models_v2/Final_df/bull_market_2_regression.csv'
}

# Initialize the results dictionary
results = {}

# Seed value for reproducibility
seed_value = 42
tf.random.set_seed(seed_value)
np.random.seed(seed_value)
random.seed(seed_value)

# Normalize the data
columns_to_scale = ['Open', 'High', 'Low', 'Volume', 'RSI', 'ATR', 'MACD', 'MFI',
                    'EMA', 'SMA', 'OBV', 'GTrends_Interest', 'Sentiment_Bullish',
                    'Price_oil', 'Price_gold', 'Price_NASDAQ', 'Price_SP500', 'Price_NYSE',
                    'Interest_Rate', 'hash_rate', 'users']

scaler = MinMaxScaler(feature_range=(0, 1))

# Define the function to create the dataset
def create_dataset(data, window_size, target_index):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data.iloc[i:(i + window_size)].values)
        y.append(data.iloc[i + window_size, target_index])
    return np.array(X), np.array(y)

# Forecast Horizon
window_size = 3
close_index = 3

# Define a model-building function
def build_model(hp):
    model = Sequential()
    model.add(Conv2D(
        filters=hp.Int('conv_1_filter', min_value=10, max_value=150, step=10),
        kernel_size=3,
        activation='relu',
        input_shape=(3, 22, 1),
        padding='same'
    ))
    model.add(MaxPooling2D(pool_size=hp.Choice('pool_1_size', values=[2, 3]), padding='same'))

    model.add(Conv2D(
        filters=hp.Int('conv_2_filter', min_value=10, max_value=150, step=10),
        kernel_size=3,
        activation='relu',
        padding='same'
    ))
    model.add(MaxPooling2D(pool_size=hp.Choice('pool_2_size', values=[2, 3]), padding='same'))

    model.add(Dense(
        hp.Int('dense_units', min_value=10, max_value=100, step=10),
        activation='relu'))
    
    x,y = model.output_shape[2], model.output_shape[3]

    model.add(Reshape((x, y)))

    model.add(LSTM(
        units=hp.Int('lstm_units', min_value=10, max_value=100, step=10),
        activation='relu',
    ))
    model.add(Dropout(rate=hp.Float('dropout_2', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Dense(units=1, activation='linear'))
    
    model.compile(optimizer=Adam(hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                  loss='mse',
                  metrics=['mae', 'mean_absolute_percentage_error'])

    return model

# Function to fit the model and evaluate metrics
def fit_and_evaluate(data, scaler, window_size, close_index, project_name):
    data[columns_to_scale] = scaler.fit_transform(data[columns_to_scale])
    training_size = int(len(data) * 0.9)
    training_data = data[:training_size]
    test_data = data[training_size:]
    train_data = training_data[:int(len(training_data) * 0.9)]
    val_data = training_data[int(len(training_data) * 0.9):]

    X_train, y_train = create_dataset(train_data, window_size, close_index)
    X_test, y_test = create_dataset(test_data, window_size, close_index)
    X_val, y_val = create_dataset(val_data, window_size, close_index)
    X_train_full, y_train_full = create_dataset(training_data, window_size, close_index)

    X_train = X_train.reshape((X_train.shape[0], window_size, X_train.shape[2], 1))
    X_test = X_test.reshape((X_test.shape[0], window_size, X_test.shape[2], 1))
    X_val = X_val.reshape((X_val.shape[0], window_size, X_val.shape[2], 1))
    X_train_full = X_train_full.reshape((X_train_full.shape[0], window_size, X_train_full.shape[2], 1))

    tuner = RandomSearch(
        build_model,
        objective='val_mean_absolute_percentage_error',
        max_trials=200,
        executions_per_trial=1,
        directory='my_dir',
        project_name=project_name,
        overwrite=False
    )

    early_stopping = EarlyStopping(monitor='val_mean_absolute_percentage_error', patience=15, restore_best_weights=True)

    tuner.search(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), verbose=2, callbacks=[early_stopping])

    best_hps = tuner.get_best_hyperparameters()[0]

    mae_list, rmse_list, mape_list = [], [], []
    for _ in range(10):
        best_model = tuner.hypermodel.build(best_hps)  
        history = best_model.fit(X_train_full, y_train_full, epochs=250, batch_size=32, verbose=2)
        predictions = best_model.predict(X_test)

        mae = mean_absolute_error(y_test, predictions)
        rmse = np.sqrt(mean_squared_error(y_test, predictions))
        mape = tf.keras.losses.MAPE(y_test, predictions)

        mae_list.append(mae)
        rmse_list.append(rmse)
        mape_list.append(np.mean(mape))

    return {
        'mae': np.mean(mae_list),
        'rmse': np.mean(rmse_list),
        'mape': np.mean(mape_list)
    }

# Process each period and store results
for period, file_path in file_paths.items():
    data = pd.read_csv(file_path)
    data['Date'] = pd.to_datetime(data['Date'])
    data.set_index('Date', inplace=True)
    project_name = f'CNNLSTM-3D-REG-{period}'
    results[period] = fit_and_evaluate(data, scaler, window_size, close_index, project_name)

# Create a DataFrame from the results
results_df = pd.DataFrame(results).T
print(results_df)

# Save the results to a CSV file
results_df.to_csv('model_performance_summary_cnn_lstm_regression.csv')
# Out:
# Trial 200 Complete [00h 00m 16s]
# val_mean_absolute_percentage_error: 4.349420547485352
#
# Best val_mean_absolute_percentage_error So Far: 3.7046937942504883
# Total elapsed time: 00h 50m 48s
# Epoch 1/250
# 31/31 - 1s - 39ms/step - loss: 507431488.0000 - mae: 16462.4570 - mean_absolute_percentage_error: 98.0473
# Epoch 2/250
# 31/31 - 0s - 4ms/step - loss: 416828448.0000 - mae: 14838.5527 - mean_absolute_percentage_error: 88.2646
# Epoch 3/250
# 31/31 - 0s - 4ms/step - loss: 56248436.0000 - mae: 4337.4829 - mean_absolute_percentage_error: 26.1548
# Epoch 4/250
# 31/31 - 0s - 4ms/step - loss: 13181655.0000 - mae: 2107.2593 - mean_absolute_percentage_error: 12.7671
# Epoch 5/250
# 31/31 - 0s - 5ms/step - loss: 12292478.0000 - mae: 2038.6893 - mean_absolute_percentage_error: 12.2558
# Epoch 6/250
# 31/31 - 0s - 5ms/step - loss: 12294659.0000 - mae: 2085.9177 - mean_absolute_percentage_error: 12.2020
# Epoch 7/250
# 31/31 - 0s - 5ms/step - loss: 11546763.0000 - mae: 1926.4722 - mean_absolute_percentage_error: 11.2227
# Epoch 8/250
# 31/31 - 0s - 5ms/step - loss: 9643056.0000 - mae: 1845.4890 - mean_absolute_percentage_error: 11.1350
# Epoch 9/250
# 31/31 - 0s - 5ms/step - loss: 11035399.0000 - mae: 1864.6355 - mean_absolute_percentage_error: 11.1531
# Epoch 10/250
# 31/31 - 0s - 5ms/step - loss: 10255338.0000 - mae: 1815.4320 - mean_absolute_percentage_error: 10.4917
# Epoch 11/250
# 31/31 - 0s - 5ms/step - loss: 9949475.0000 - mae: 1812.5024 - mean_absolute_percentage_error: 10.8134
# Epoch 12/250
# 31/31 - 0s - 5ms/step - loss: 10330970.0000 - mae: 1840.8121 - mean_absolute_percentage_error: 10.6953
# Epoch 13/250
# 31/31 - 0s - 5ms/step - loss: 11604442.0000 - mae: 1867.6560 - mean_absolute_percentage_error: 10.7416
# Epoch 14/250
# 31/31 - 0s - 5ms/step - loss: 8900048.0000 - mae: 1662.3722 - mean_absolute_percentage_error: 9.6447
# Epoch 15/250
# 31/31 - 0s - 5ms/step - loss: 8881913.0000 - mae: 1722.8042 - mean_absolute_percentage_error: 9.9862
# Epoch 16/250
# 31/31 - 0s - 5ms/step - loss: 9228503.0000 - mae: 1737.9985 - mean_absolute_percentage_error: 10.2766
# Epoch 17/250
# 31/31 - 0s - 5ms/step - loss: 7318781.0000 - mae: 1587.2271 - mean_absolute_percentage_error: 9.6473
# Epoch 18/250
# 31/31 - 0s - 5ms/step - loss: 7746078.0000 - mae: 1602.6846 - mean_absolute_percentage_error: 9.6287
# Epoch 19/250
# 31/31 - 0s - 5ms/step - loss: 6196803.0000 - mae: 1522.6283 - mean_absolute_percentage_error: 9.5397
# Epoch 20/250
# 31/31 - 0s - 4ms/step - loss: 8919429.0000 - mae: 1668.3585 - mean_absolute_percentage_error: 9.7913
# Epoch 21/250
# 31/31 - 0s - 4ms/step - loss: 6889252.0000 - mae: 1546.1312 - mean_absolute_percentage_error: 9.4741
# Epoch 22/250
# 31/31 - 0s - 5ms/step - loss: 7798430.5000 - mae: 1647.9707 - mean_absolute_percentage_error: 9.6540
# Epoch 23/250
# 31/31 - 0s - 5ms/step - loss: 8697757.0000 - mae: 1692.6279 - mean_absolute_percentage_error: 9.8290
# Epoch 24/250
# 31/31 - 0s - 5ms/step - loss: 7497905.0000 - mae: 1614.1456 - mean_absolute_percentage_error: 9.5496
# Epoch 25/250
# 31/31 - 0s - 5ms/step - loss: 7843937.0000 - mae: 1621.2188 - mean_absolute_percentage_error: 9.5003
# Epoch 26/250
# 31/31 - 0s - 5ms/step - loss: 7509108.5000 - mae: 1617.5459 - mean_absolute_percentage_error: 9.4935
# Epoch 27/250
# 31/31 - 0s - 5ms/step - loss: 7904204.5000 - mae: 1627.0430 - mean_absolute_percentage_error: 9.5886
# Epoch 28/250
# 31/31 - 0s - 5ms/step - loss: 7172467.0000 - mae: 1598.9144 - mean_absolute_percentage_error: 9.4144
# Epoch 29/250
# 31/31 - 0s - 5ms/step - loss: 8430831.0000 - mae: 1650.3574 - mean_absolute_percentage_error: 9.3244
# Epoch 30/250
# 31/31 - 0s - 7ms/step - loss: 8277811.0000 - mae: 1670.9320 - mean_absolute_percentage_error: 9.7732
# Epoch 31/250
# 31/31 - 0s - 5ms/step - loss: 7301749.0000 - mae: 1582.8555 - mean_absolute_percentage_error: 9.3805
# Epoch 32/250
# 31/31 - 0s - 5ms/step - loss: 6529709.5000 - mae: 1473.4695 - mean_absolute_percentage_error: 8.8852
# Epoch 33/250
# 31/31 - 0s - 5ms/step - loss: 8177356.5000 - mae: 1629.1049 - mean_absolute_percentage_error: 9.2837
# Epoch 34/250
# 31/31 - 0s - 5ms/step - loss: 7132955.5000 - mae: 1549.2190 - mean_absolute_percentage_error: 8.9550
# Epoch 35/250
# 31/31 - 0s - 5ms/step - loss: 6423726.5000 - mae: 1510.7136 - mean_absolute_percentage_error: 9.2408
# Epoch 36/250
# 31/31 - 0s - 5ms/step - loss: 8194872.0000 - mae: 1588.4325 - mean_absolute_percentage_error: 9.0142
# Epoch 37/250
# 31/31 - 0s - 5ms/step - loss: 8295532.0000 - mae: 1614.7360 - mean_absolute_percentage_error: 9.2092
# Epoch 38/250
# 31/31 - 0s - 5ms/step - loss: 6357795.5000 - mae: 1528.8425 - mean_absolute_percentage_error: 9.1957
# Epoch 39/250
# 31/31 - 0s - 5ms/step - loss: 7111512.0000 - mae: 1595.3175 - mean_absolute_percentage_error: 9.5337
# Epoch 40/250
# 31/31 - 0s - 5ms/step - loss: 6481158.0000 - mae: 1508.2177 - mean_absolute_percentage_error: 8.9273
# Epoch 41/250
# 31/31 - 0s - 5ms/step - loss: 7687571.5000 - mae: 1558.9492 - mean_absolute_percentage_error: 9.0083
# Epoch 42/250
# 31/31 - 0s - 5ms/step - loss: 7481499.0000 - mae: 1562.6267 - mean_absolute_percentage_error: 9.0063
# Epoch 43/250
# 31/31 - 0s - 5ms/step - loss: 7288356.5000 - mae: 1585.7827 - mean_absolute_percentage_error: 9.2842
# Epoch 44/250
# 31/31 - 0s - 5ms/step - loss: 6634890.5000 - mae: 1507.3495 - mean_absolute_percentage_error: 8.9247
# Epoch 45/250
# 31/31 - 0s - 5ms/step - loss: 7225633.0000 - mae: 1552.6305 - mean_absolute_percentage_error: 9.3480
# Epoch 46/250
# 31/31 - 0s - 5ms/step - loss: 6155958.5000 - mae: 1472.3359 - mean_absolute_percentage_error: 8.8038
# Epoch 47/250
# 31/31 - 0s - 5ms/step - loss: 7547541.5000 - mae: 1546.7241 - mean_absolute_percentage_error: 8.8745
# Epoch 48/250
# 31/31 - 0s - 5ms/step - loss: 6477695.0000 - mae: 1471.4807 - mean_absolute_percentage_error: 8.6123
# Epoch 49/250
# 31/31 - 0s - 5ms/step - loss: 6801042.0000 - mae: 1504.8621 - mean_absolute_percentage_error: 8.8613
# Epoch 50/250
# 31/31 - 0s - 5ms/step - loss: 7623929.0000 - mae: 1553.9700 - mean_absolute_percentage_error: 8.8082
# Epoch 51/250
# 31/31 - 0s - 5ms/step - loss: 7352872.0000 - mae: 1606.2798 - mean_absolute_percentage_error: 9.7810
# Epoch 52/250
# 31/31 - 0s - 5ms/step - loss: 7652831.5000 - mae: 1604.9399 - mean_absolute_percentage_error: 9.2281
# Epoch 53/250
# 31/31 - 0s - 5ms/step - loss: 6930023.5000 - mae: 1543.7518 - mean_absolute_percentage_error: 9.1177
# Epoch 54/250
# 31/31 - 0s - 5ms/step - loss: 8238081.5000 - mae: 1621.4971 - mean_absolute_percentage_error: 9.0961
# Epoch 55/250
# 31/31 - 0s - 5ms/step - loss: 7497953.0000 - mae: 1564.3007 - mean_absolute_percentage_error: 9.1848
# Epoch 56/250
# 31/31 - 0s - 5ms/step - loss: 7409823.0000 - mae: 1623.2390 - mean_absolute_percentage_error: 9.5954
# Epoch 57/250
# 31/31 - 0s - 5ms/step - loss: 7795961.5000 - mae: 1569.7783 - mean_absolute_percentage_error: 8.8042
# Epoch 58/250
# 31/31 - 0s - 5ms/step - loss: 6625269.0000 - mae: 1528.8829 - mean_absolute_percentage_error: 9.4439
# Epoch 59/250
# 31/31 - 0s - 5ms/step - loss: 6689358.0000 - mae: 1539.5079 - mean_absolute_percentage_error: 9.0148
# Epoch 60/250
# 31/31 - 0s - 5ms/step - loss: 7357956.5000 - mae: 1640.9968 - mean_absolute_percentage_error: 10.1180
# Epoch 61/250
# 31/31 - 0s - 5ms/step - loss: 6534204.0000 - mae: 1518.1906 - mean_absolute_percentage_error: 9.2227
# Epoch 62/250
# 31/31 - 0s - 5ms/step - loss: 6417549.0000 - mae: 1465.2218 - mean_absolute_percentage_error: 8.8781
# Epoch 63/250
# 31/31 - 0s - 5ms/step - loss: 6938816.0000 - mae: 1545.8975 - mean_absolute_percentage_error: 9.0786
# Epoch 64/250
# 31/31 - 0s - 5ms/step - loss: 5970508.5000 - mae: 1438.6089 - mean_absolute_percentage_error: 8.6839
# Epoch 65/250
# 31/31 - 0s - 5ms/step - loss: 7458854.5000 - mae: 1594.2914 - mean_absolute_percentage_error: 9.2996
# Epoch 66/250
# 31/31 - 0s - 5ms/step - loss: 7984454.5000 - mae: 1611.1288 - mean_absolute_percentage_error: 9.3722
# Epoch 67/250
# 31/31 - 0s - 5ms/step - loss: 7488341.0000 - mae: 1557.9418 - mean_absolute_percentage_error: 8.8952
# Epoch 68/250
# 31/31 - 0s - 5ms/step - loss: 7272931.5000 - mae: 1597.6460 - mean_absolute_percentage_error: 9.5651
# Epoch 69/250
# 31/31 - 0s - 5ms/step - loss: 6019704.5000 - mae: 1476.3802 - mean_absolute_percentage_error: 8.9483
# Epoch 70/250
# 31/31 - 0s - 5ms/step - loss: 7892045.5000 - mae: 1621.3372 - mean_absolute_percentage_error: 9.1795
# Epoch 71/250
# 31/31 - 0s - 5ms/step - loss: 6729298.0000 - mae: 1530.7578 - mean_absolute_percentage_error: 9.2523
# Epoch 72/250
# 31/31 - 0s - 5ms/step - loss: 6078563.0000 - mae: 1463.4291 - mean_absolute_percentage_error: 8.8390
# Epoch 73/250
# 31/31 - 0s - 5ms/step - loss: 6571451.5000 - mae: 1490.3271 - mean_absolute_percentage_error: 8.7820
# Epoch 74/250
# 31/31 - 0s - 6ms/step - loss: 7305699.0000 - mae: 1596.6887 - mean_absolute_percentage_error: 9.2558
# Epoch 75/250
# 31/31 - 0s - 5ms/step - loss: 8226693.0000 - mae: 1684.9783 - mean_absolute_percentage_error: 9.9245
# Epoch 76/250
# 31/31 - 0s - 5ms/step - loss: 7084918.0000 - mae: 1578.3704 - mean_absolute_percentage_error: 9.3484
# Epoch 77/250
# 31/31 - 0s - 5ms/step - loss: 6976981.0000 - mae: 1522.2374 - mean_absolute_percentage_error: 8.8484
# Epoch 78/250
# 31/31 - 0s - 5ms/step - loss: 6940532.5000 - mae: 1548.6517 - mean_absolute_percentage_error: 9.0651
# Epoch 79/250
# 31/31 - 0s - 5ms/step - loss: 6819418.0000 - mae: 1476.6066 - mean_absolute_percentage_error: 8.5388
# Epoch 80/250
# 31/31 - 0s - 5ms/step - loss: 7848588.0000 - mae: 1559.1376 - mean_absolute_percentage_error: 8.8110
# Epoch 81/250
# 31/31 - 0s - 5ms/step - loss: 6084659.5000 - mae: 1492.4292 - mean_absolute_percentage_error: 9.0591
# Epoch 82/250
# 31/31 - 0s - 5ms/step - loss: 6566071.0000 - mae: 1464.5822 - mean_absolute_percentage_error: 8.4713
# Epoch 83/250
# 31/31 - 0s - 5ms/step - loss: 6865069.5000 - mae: 1500.9487 - mean_absolute_percentage_error: 8.4705
# Epoch 84/250
# 31/31 - 0s - 5ms/step - loss: 6100549.0000 - mae: 1461.7158 - mean_absolute_percentage_error: 8.6528
# Epoch 85/250
# 31/31 - 0s - 5ms/step - loss: 5885632.0000 - mae: 1388.8217 - mean_absolute_percentage_error: 7.9674
# Epoch 86/250
# 31/31 - 0s - 5ms/step - loss: 7027482.5000 - mae: 1570.1190 - mean_absolute_percentage_error: 8.9639
# Epoch 87/250
# 31/31 - 0s - 5ms/step - loss: 5273727.5000 - mae: 1335.3972 - mean_absolute_percentage_error: 7.9267
# Epoch 88/250
# 31/31 - 0s - 5ms/step - loss: 6864247.0000 - mae: 1507.6544 - mean_absolute_percentage_error: 8.8216
# Epoch 89/250
# 31/31 - 0s - 5ms/step - loss: 6291097.0000 - mae: 1470.9368 - mean_absolute_percentage_error: 8.8566
# Epoch 90/250
# 31/31 - 0s - 5ms/step - loss: 6056396.0000 - mae: 1438.2892 - mean_absolute_percentage_error: 8.5578
# Epoch 91/250
# 31/31 - 0s - 5ms/step - loss: 6974798.0000 - mae: 1533.1123 - mean_absolute_percentage_error: 8.8926
# Epoch 92/250
# 31/31 - 0s - 5ms/step - loss: 5818083.5000 - mae: 1454.1384 - mean_absolute_percentage_error: 8.6653
# Epoch 93/250
# 31/31 - 0s - 5ms/step - loss: 6867456.0000 - mae: 1521.6132 - mean_absolute_percentage_error: 8.7458
# Epoch 94/250
# 31/31 - 0s - 5ms/step - loss: 5213027.0000 - mae: 1343.7743 - mean_absolute_percentage_error: 8.0688
# Epoch 95/250
# 31/31 - 0s - 5ms/step - loss: 6546716.0000 - mae: 1474.5043 - mean_absolute_percentage_error: 8.6613
# Epoch 96/250
# 31/31 - 0s - 5ms/step - loss: 6352568.0000 - mae: 1492.0508 - mean_absolute_percentage_error: 9.0212
# Epoch 97/250
# 31/31 - 0s - 5ms/step - loss: 7534301.0000 - mae: 1557.9711 - mean_absolute_percentage_error: 9.3928
# Epoch 98/250
# 31/31 - 0s - 5ms/step - loss: 8237066.0000 - mae: 1678.1062 - mean_absolute_percentage_error: 9.8425
# Epoch 99/250
# 31/31 - 0s - 5ms/step - loss: 6074344.0000 - mae: 1420.9453 - mean_absolute_percentage_error: 8.5551
# Epoch 100/250
# 31/31 - 0s - 5ms/step - loss: 7332469.5000 - mae: 1584.0040 - mean_absolute_percentage_error: 9.3421
# Epoch 101/250
# 31/31 - 0s - 5ms/step - loss: 7973185.5000 - mae: 1606.3154 - mean_absolute_percentage_error: 9.1471
# Epoch 102/250
# 31/31 - 0s - 5ms/step - loss: 6619369.5000 - mae: 1462.0352 - mean_absolute_percentage_error: 8.7391
# Epoch 103/250
# 31/31 - 0s - 5ms/step - loss: 7516371.5000 - mae: 1584.8094 - mean_absolute_percentage_error: 9.3248
# Epoch 104/250
# 31/31 - 0s - 5ms/step - loss: 7895968.5000 - mae: 1621.3140 - mean_absolute_percentage_error: 9.3823
# Epoch 105/250
# 31/31 - 0s - 5ms/step - loss: 6624817.0000 - mae: 1525.5548 - mean_absolute_percentage_error: 9.2478
# Epoch 106/250
# 31/31 - 0s - 5ms/step - loss: 7966430.0000 - mae: 1617.1720 - mean_absolute_percentage_error: 9.5806
# Epoch 107/250
# 31/31 - 0s - 5ms/step - loss: 6391345.0000 - mae: 1524.0808 - mean_absolute_percentage_error: 9.0802
# Epoch 108/250
# 31/31 - 0s - 5ms/step - loss: 5972650.5000 - mae: 1428.5570 - mean_absolute_percentage_error: 8.5245
# Epoch 109/250
# 31/31 - 0s - 5ms/step - loss: 7865704.0000 - mae: 1583.2194 - mean_absolute_percentage_error: 9.2676
# Epoch 110/250
# 31/31 - 0s - 5ms/step - loss: 7721612.0000 - mae: 1579.2732 - mean_absolute_percentage_error: 8.9328
# Epoch 111/250
# 31/31 - 0s - 5ms/step - loss: 7325397.0000 - mae: 1592.3970 - mean_absolute_percentage_error: 9.2141
# Epoch 112/250
# 31/31 - 0s - 5ms/step - loss: 6661016.5000 - mae: 1540.7236 - mean_absolute_percentage_error: 9.2755
# Epoch 113/250
# 31/31 - 0s - 5ms/step - loss: 7593950.5000 - mae: 1556.1388 - mean_absolute_percentage_error: 8.7947
# Epoch 114/250
# 31/31 - 0s - 5ms/step - loss: 6371194.5000 - mae: 1508.0415 - mean_absolute_percentage_error: 9.1864
# Epoch 115/250
# 31/31 - 0s - 5ms/step - loss: 5900030.5000 - mae: 1404.7556 - mean_absolute_percentage_error: 8.2198
# Epoch 116/250
# 31/31 - 0s - 5ms/step - loss: 7894436.5000 - mae: 1623.5947 - mean_absolute_percentage_error: 9.7632
# Epoch 117/250
# 31/31 - 0s - 5ms/step - loss: 8643554.0000 - mae: 1763.4178 - mean_absolute_percentage_error: 10.5375
# Epoch 118/250
# 31/31 - 0s - 6ms/step - loss: 5658768.5000 - mae: 1427.2518 - mean_absolute_percentage_error: 8.7066
# Epoch 119/250
# 31/31 - 0s - 5ms/step - loss: 7283127.0000 - mae: 1576.6680 - mean_absolute_percentage_error: 9.1398
# Epoch 120/250
# 31/31 - 0s - 8ms/step - loss: 6186840.0000 - mae: 1447.0798 - mean_absolute_percentage_error: 8.5012
# Epoch 121/250
# 31/31 - 0s - 5ms/step - loss: 7906564.5000 - mae: 1615.7832 - mean_absolute_percentage_error: 9.2811
# Epoch 122/250
# 31/31 - 0s - 5ms/step - loss: 6162517.0000 - mae: 1497.7831 - mean_absolute_percentage_error: 9.1935
# Epoch 123/250
# 31/31 - 0s - 5ms/step - loss: 6543734.5000 - mae: 1508.2655 - mean_absolute_percentage_error: 8.8684
# Epoch 124/250
# 31/31 - 0s - 5ms/step - loss: 6238873.0000 - mae: 1483.5828 - mean_absolute_percentage_error: 8.7414
# Epoch 125/250
# 31/31 - 0s - 5ms/step - loss: 6937720.0000 - mae: 1540.5439 - mean_absolute_percentage_error: 9.0724
# Epoch 126/250
# 31/31 - 0s - 5ms/step - loss: 7552708.5000 - mae: 1568.5759 - mean_absolute_percentage_error: 9.0730
# Epoch 127/250
# 31/31 - 0s - 5ms/step - loss: 6446859.0000 - mae: 1469.3314 - mean_absolute_percentage_error: 8.7485
# Epoch 128/250
# 31/31 - 0s - 5ms/step - loss: 8180006.5000 - mae: 1630.3733 - mean_absolute_percentage_error: 9.2216
# Epoch 129/250
# 31/31 - 0s - 5ms/step - loss: 6843818.5000 - mae: 1522.7236 - mean_absolute_percentage_error: 8.5908
# Epoch 130/250
# 31/31 - 0s - 5ms/step - loss: 5846819.5000 - mae: 1417.3068 - mean_absolute_percentage_error: 8.4922
# Epoch 131/250
# 31/31 - 0s - 5ms/step - loss: 7021746.5000 - mae: 1586.9219 - mean_absolute_percentage_error: 9.2757
# Epoch 132/250
# 31/31 - 0s - 4ms/step - loss: 7742219.5000 - mae: 1632.8994 - mean_absolute_percentage_error: 9.4770
# Epoch 133/250
# 31/31 - 0s - 4ms/step - loss: 5946116.5000 - mae: 1440.5355 - mean_absolute_percentage_error: 8.5481
# Epoch 134/250
# 31/31 - 0s - 5ms/step - loss: 7600807.5000 - mae: 1610.8407 - mean_absolute_percentage_error: 9.3237
# Epoch 135/250
# 31/31 - 0s - 4ms/step - loss: 5668307.0000 - mae: 1444.3303 - mean_absolute_percentage_error: 8.9624
# Epoch 136/250
# 31/31 - 0s - 5ms/step - loss: 7034788.0000 - mae: 1556.2177 - mean_absolute_percentage_error: 9.2213
# Epoch 137/250
# 31/31 - 0s - 5ms/step - loss: 6383432.0000 - mae: 1475.2682 - mean_absolute_percentage_error: 8.7171
# Epoch 138/250
# 31/31 - 0s - 5ms/step - loss: 7330518.5000 - mae: 1560.0708 - mean_absolute_percentage_error: 9.2492
# Epoch 139/250
# 31/31 - 0s - 5ms/step - loss: 6945196.5000 - mae: 1534.5696 - mean_absolute_percentage_error: 9.0026
# Epoch 140/250
# 31/31 - 0s - 5ms/step - loss: 6558990.5000 - mae: 1474.9467 - mean_absolute_percentage_error: 8.6105
# Epoch 141/250
# 31/31 - 0s - 5ms/step - loss: 5535179.0000 - mae: 1409.7249 - mean_absolute_percentage_error: 8.4062
# Epoch 142/250
# 31/31 - 0s - 5ms/step - loss: 6171836.5000 - mae: 1442.9480 - mean_absolute_percentage_error: 8.5564
# Epoch 143/250
# 31/31 - 0s - 5ms/step - loss: 7665540.5000 - mae: 1552.1118 - mean_absolute_percentage_error: 8.9056
# Epoch 144/250
# 31/31 - 0s - 5ms/step - loss: 6590683.0000 - mae: 1499.3347 - mean_absolute_percentage_error: 8.6726
# Epoch 145/250
# 31/31 - 0s - 5ms/step - loss: 6392936.0000 - mae: 1428.2953 - mean_absolute_percentage_error: 8.3336
# Epoch 146/250
# 31/31 - 0s - 5ms/step - loss: 6790104.5000 - mae: 1515.1930 - mean_absolute_percentage_error: 9.0025
# Epoch 147/250
# 31/31 - 0s - 5ms/step - loss: 6811223.0000 - mae: 1473.9343 - mean_absolute_percentage_error: 8.6351
# Epoch 148/250
# 31/31 - 0s - 5ms/step - loss: 5861249.0000 - mae: 1377.4845 - mean_absolute_percentage_error: 8.1104
# Epoch 149/250
# 31/31 - 0s - 5ms/step - loss: 7228333.5000 - mae: 1536.2268 - mean_absolute_percentage_error: 9.1848
# Epoch 150/250
# 31/31 - 0s - 5ms/step - loss: 8008858.5000 - mae: 1669.4438 - mean_absolute_percentage_error: 9.9937
# Epoch 151/250
# 31/31 - 0s - 5ms/step - loss: 8149222.0000 - mae: 1645.3518 - mean_absolute_percentage_error: 9.3585
# Epoch 152/250
# 31/31 - 0s - 5ms/step - loss: 6764776.0000 - mae: 1432.2103 - mean_absolute_percentage_error: 8.5564
# Epoch 153/250
# 31/31 - 0s - 5ms/step - loss: 6069633.5000 - mae: 1400.4209 - mean_absolute_percentage_error: 8.3131
# Epoch 154/250
# 31/31 - 0s - 5ms/step - loss: 6603510.5000 - mae: 1499.0608 - mean_absolute_percentage_error: 8.9162
# Epoch 155/250
# 31/31 - 0s - 5ms/step - loss: 5402093.5000 - mae: 1370.4280 - mean_absolute_percentage_error: 8.1458
# Epoch 156/250
# 31/31 - 0s - 5ms/step - loss: 5949502.0000 - mae: 1443.1823 - mean_absolute_percentage_error: 8.5434
# Epoch 157/250
# 31/31 - 0s - 5ms/step - loss: 6786431.0000 - mae: 1504.5232 - mean_absolute_percentage_error: 8.7934
# Epoch 158/250
# 31/31 - 0s - 5ms/step - loss: 8854112.0000 - mae: 1778.2288 - mean_absolute_percentage_error: 10.7273
# Epoch 159/250
# 31/31 - 0s - 5ms/step - loss: 7941893.5000 - mae: 1674.6184 - mean_absolute_percentage_error: 9.4961
# Epoch 160/250
# 31/31 - 0s - 5ms/step - loss: 8237718.5000 - mae: 1670.9442 - mean_absolute_percentage_error: 9.9257
# Epoch 161/250
# 31/31 - 0s - 5ms/step - loss: 5998445.5000 - mae: 1439.1078 - mean_absolute_percentage_error: 8.5169
# Epoch 162/250
# 31/31 - 0s - 6ms/step - loss: 6908991.5000 - mae: 1476.1882 - mean_absolute_percentage_error: 8.4034
# Epoch 163/250
# 31/31 - 0s - 5ms/step - loss: 7691473.5000 - mae: 1580.5306 - mean_absolute_percentage_error: 9.3452
# Epoch 164/250
# 31/31 - 0s - 5ms/step - loss: 6028906.0000 - mae: 1427.6580 - mean_absolute_percentage_error: 8.6121
# Epoch 165/250
# 31/31 - 0s - 5ms/step - loss: 6049031.5000 - mae: 1408.6765 - mean_absolute_percentage_error: 8.4401
# Epoch 166/250
# 31/31 - 0s - 5ms/step - loss: 7099815.5000 - mae: 1503.4401 - mean_absolute_percentage_error: 8.7788
# Epoch 167/250
# 31/31 - 0s - 5ms/step - loss: 7434111.5000 - mae: 1586.9159 - mean_absolute_percentage_error: 9.3850
# Epoch 168/250
# 31/31 - 0s - 5ms/step - loss: 7833019.5000 - mae: 1667.4288 - mean_absolute_percentage_error: 9.8092
# Epoch 169/250
# 31/31 - 0s - 5ms/step - loss: 6542437.5000 - mae: 1509.0426 - mean_absolute_percentage_error: 8.9825
# Epoch 170/250
# 31/31 - 0s - 5ms/step - loss: 7724023.0000 - mae: 1637.4608 - mean_absolute_percentage_error: 9.1823
# Epoch 171/250
# 31/31 - 0s - 5ms/step - loss: 5530337.0000 - mae: 1355.9814 - mean_absolute_percentage_error: 8.2429
# Epoch 172/250
# 31/31 - 0s - 5ms/step - loss: 6481232.0000 - mae: 1503.1298 - mean_absolute_percentage_error: 8.9116
# Epoch 173/250
# 31/31 - 0s - 5ms/step - loss: 5968389.5000 - mae: 1410.6710 - mean_absolute_percentage_error: 8.5453
# Epoch 174/250
# 31/31 - 0s - 5ms/step - loss: 6302782.0000 - mae: 1490.5248 - mean_absolute_percentage_error: 8.4141
# Epoch 175/250
# 31/31 - 0s - 5ms/step - loss: 6065484.5000 - mae: 1399.3992 - mean_absolute_percentage_error: 8.2961
# Epoch 176/250
# 31/31 - 0s - 5ms/step - loss: 6815141.5000 - mae: 1508.1798 - mean_absolute_percentage_error: 8.9091
# Epoch 177/250
# 31/31 - 0s - 5ms/step - loss: 7077129.0000 - mae: 1541.0000 - mean_absolute_percentage_error: 8.8872
# Epoch 178/250
# 31/31 - 0s - 5ms/step - loss: 6907422.5000 - mae: 1515.7814 - mean_absolute_percentage_error: 8.9876
# Epoch 179/250
# 31/31 - 0s - 5ms/step - loss: 7404831.0000 - mae: 1606.1992 - mean_absolute_percentage_error: 9.5742
# Epoch 180/250
# 31/31 - 0s - 5ms/step - loss: 28679508.0000 - mae: 3086.3818 - mean_absolute_percentage_error: 18.0898
# Epoch 181/250
# 31/31 - 0s - 5ms/step - loss: 28219350.0000 - mae: 3124.7566 - mean_absolute_percentage_error: 18.7905
# Epoch 182/250
# 31/31 - 0s - 5ms/step - loss: 19342334.0000 - mae: 2444.1099 - mean_absolute_percentage_error: 14.3109
# Epoch 183/250
# 31/31 - 0s - 5ms/step - loss: 16936006.0000 - mae: 2327.9392 - mean_absolute_percentage_error: 13.4232
# Epoch 184/250
# 31/31 - 0s - 5ms/step - loss: 14086716.0000 - mae: 2189.7874 - mean_absolute_percentage_error: 12.9868
# Epoch 185/250
# 31/31 - 0s - 5ms/step - loss: 13099482.0000 - mae: 2077.3545 - mean_absolute_percentage_error: 12.4178
# Epoch 186/250
# 31/31 - 0s - 5ms/step - loss: 15418566.0000 - mae: 2301.4417 - mean_absolute_percentage_error: 13.4305
# Epoch 187/250
# 31/31 - 0s - 5ms/step - loss: 14579287.0000 - mae: 2222.0208 - mean_absolute_percentage_error: 13.0863
# Epoch 188/250
# 31/31 - 0s - 5ms/step - loss: 15521516.0000 - mae: 2293.3904 - mean_absolute_percentage_error: 13.2449
# Epoch 189/250
# 31/31 - 0s - 5ms/step - loss: 16611020.0000 - mae: 2311.9604 - mean_absolute_percentage_error: 13.1946
# Epoch 190/250
# 31/31 - 0s - 5ms/step - loss: 14714691.0000 - mae: 2195.2903 - mean_absolute_percentage_error: 13.0234
# Epoch 191/250
# 31/31 - 0s - 5ms/step - loss: 13665870.0000 - mae: 2098.4590 - mean_absolute_percentage_error: 11.8953
# Epoch 192/250
# 31/31 - 0s - 4ms/step - loss: 13376031.0000 - mae: 2093.6262 - mean_absolute_percentage_error: 12.7472
# Epoch 193/250
# 31/31 - 0s - 5ms/step - loss: 14738797.0000 - mae: 2232.6030 - mean_absolute_percentage_error: 13.2951
# Epoch 194/250
# 31/31 - 0s - 4ms/step - loss: 14956683.0000 - mae: 2209.1655 - mean_absolute_percentage_error: 13.1119
# Epoch 195/250
# 31/31 - 0s - 5ms/step - loss: 14012718.0000 - mae: 2151.7969 - mean_absolute_percentage_error: 12.5898
# Epoch 196/250
# 31/31 - 0s - 5ms/step - loss: 13352510.0000 - mae: 2224.6279 - mean_absolute_percentage_error: 13.6754
# Epoch 197/250
# 31/31 - 0s - 5ms/step - loss: 13883082.0000 - mae: 2177.9517 - mean_absolute_percentage_error: 13.0202
# Epoch 198/250
# 31/31 - 0s - 5ms/step - loss: 13969667.0000 - mae: 2166.3643 - mean_absolute_percentage_error: 12.7518
# Epoch 199/250
# 31/31 - 0s - 5ms/step - loss: 15523938.0000 - mae: 2233.2749 - mean_absolute_percentage_error: 13.1123
# Epoch 200/250
# 31/31 - 0s - 5ms/step - loss: 12711571.0000 - mae: 2131.3342 - mean_absolute_percentage_error: 13.1486
# Epoch 201/250
# 31/31 - 0s - 5ms/step - loss: 13691535.0000 - mae: 2156.5205 - mean_absolute_percentage_error: 12.5845
# Epoch 202/250
# 31/31 - 0s - 5ms/step - loss: 12906416.0000 - mae: 2135.0818 - mean_absolute_percentage_error: 12.7140
# Epoch 203/250
# 31/31 - 0s - 5ms/step - loss: 14613648.0000 - mae: 2195.5850 - mean_absolute_percentage_error: 12.9812
# Epoch 204/250
# 31/31 - 0s - 5ms/step - loss: 13658291.0000 - mae: 2141.5576 - mean_absolute_percentage_error: 12.6720
# Epoch 205/250
# 31/31 - 0s - 5ms/step - loss: 14640835.0000 - mae: 2118.4224 - mean_absolute_percentage_error: 12.4404
# Epoch 206/250
# 31/31 - 0s - 6ms/step - loss: 12352858.0000 - mae: 2035.8954 - mean_absolute_percentage_error: 12.4465
# Epoch 207/250
# 31/31 - 0s - 5ms/step - loss: 15342234.0000 - mae: 2251.8240 - mean_absolute_percentage_error: 13.0939
# Epoch 208/250
# 31/31 - 0s - 5ms/step - loss: 15000849.0000 - mae: 2185.0190 - mean_absolute_percentage_error: 12.5071
# Epoch 209/250
# 31/31 - 0s - 5ms/step - loss: 14148383.0000 - mae: 2188.9900 - mean_absolute_percentage_error: 12.7858
# Epoch 210/250
# 31/31 - 0s - 5ms/step - loss: 14535840.0000 - mae: 2121.1819 - mean_absolute_percentage_error: 12.3534
# Epoch 211/250
# 31/31 - 0s - 5ms/step - loss: 12560537.0000 - mae: 2069.2354 - mean_absolute_percentage_error: 12.4938
# Epoch 212/250
# 31/31 - 0s - 5ms/step - loss: 14399189.0000 - mae: 2197.6179 - mean_absolute_percentage_error: 13.2737
# Epoch 213/250
# 31/31 - 0s - 5ms/step - loss: 16710218.0000 - mae: 2470.8682 - mean_absolute_percentage_error: 14.6349
# Epoch 214/250
# 31/31 - 0s - 5ms/step - loss: 12777030.0000 - mae: 2098.9934 - mean_absolute_percentage_error: 12.2489
# Epoch 215/250
# 31/31 - 0s - 5ms/step - loss: 11460816.0000 - mae: 2082.7249 - mean_absolute_percentage_error: 12.6858
# Epoch 216/250
# 31/31 - 0s - 5ms/step - loss: 14622480.0000 - mae: 2177.2222 - mean_absolute_percentage_error: 12.6531
# Epoch 217/250
# 31/31 - 0s - 10ms/step - loss: 14573998.0000 - mae: 2146.0542 - mean_absolute_percentage_error: 12.6467
# Epoch 218/250
# 31/31 - 0s - 5ms/step - loss: 12870036.0000 - mae: 2042.4386 - mean_absolute_percentage_error: 11.9833
# Epoch 219/250
# 31/31 - 0s - 5ms/step - loss: 11701090.0000 - mae: 1922.2953 - mean_absolute_percentage_error: 11.7560
# Epoch 220/250
# 31/31 - 0s - 5ms/step - loss: 11903651.0000 - mae: 2027.7847 - mean_absolute_percentage_error: 12.4301
# Epoch 221/250
# 31/31 - 0s - 5ms/step - loss: 12362288.0000 - mae: 2054.6348 - mean_absolute_percentage_error: 12.2890
# Epoch 222/250
# 31/31 - 0s - 5ms/step - loss: 12844851.0000 - mae: 2112.5989 - mean_absolute_percentage_error: 12.4060
# Epoch 223/250
# 31/31 - 0s - 5ms/step - loss: 12579565.0000 - mae: 2128.3718 - mean_absolute_percentage_error: 12.4648
# Epoch 224/250
# 31/31 - 0s - 6ms/step - loss: 10691217.0000 - mae: 1967.8838 - mean_absolute_percentage_error: 12.1976
# Epoch 225/250
# 31/31 - 0s - 5ms/step - loss: 11062417.0000 - mae: 1959.4485 - mean_absolute_percentage_error: 11.6986
# Epoch 226/250
# 31/31 - 0s - 5ms/step - loss: 11982990.0000 - mae: 2078.3999 - mean_absolute_percentage_error: 12.5376
# Epoch 227/250
# 31/31 - 0s - 5ms/step - loss: 11317033.0000 - mae: 1945.7146 - mean_absolute_percentage_error: 11.6789
# Epoch 228/250
# 31/31 - 0s - 5ms/step - loss: 14140762.0000 - mae: 2174.9170 - mean_absolute_percentage_error: 12.3228
# Epoch 229/250
# 31/31 - 0s - 6ms/step - loss: 11703227.0000 - mae: 2054.7500 - mean_absolute_percentage_error: 12.6121
# Epoch 230/250
# 31/31 - 0s - 5ms/step - loss: 13856048.0000 - mae: 2068.3250 - mean_absolute_percentage_error: 12.0630
# Epoch 231/250
# 31/31 - 0s - 5ms/step - loss: 14071009.0000 - mae: 2090.9011 - mean_absolute_percentage_error: 12.3083
# Epoch 232/250
# 31/31 - 0s - 5ms/step - loss: 11967544.0000 - mae: 2021.3610 - mean_absolute_percentage_error: 12.2057
# Epoch 233/250
# 31/31 - 0s - 5ms/step - loss: 12737766.0000 - mae: 2051.7437 - mean_absolute_percentage_error: 12.0802
# Epoch 234/250
# 31/31 - 0s - 5ms/step - loss: 10318513.0000 - mae: 1905.9805 - mean_absolute_percentage_error: 11.7844
# Epoch 235/250
# 31/31 - 0s - 5ms/step - loss: 9912984.0000 - mae: 1916.9957 - mean_absolute_percentage_error: 11.6069
# Epoch 236/250
# 31/31 - 0s - 5ms/step - loss: 11749601.0000 - mae: 2001.4484 - mean_absolute_percentage_error: 11.8832
# Epoch 237/250
# 31/31 - 0s - 5ms/step - loss: 11993742.0000 - mae: 2014.7322 - mean_absolute_percentage_error: 11.9515
# Epoch 238/250
# 31/31 - 0s - 5ms/step - loss: 11354622.0000 - mae: 1983.5854 - mean_absolute_percentage_error: 11.9068
# Epoch 239/250
# 31/31 - 0s - 5ms/step - loss: 12494240.0000 - mae: 2038.9208 - mean_absolute_percentage_error: 11.9199
# Epoch 240/250
# 31/31 - 0s - 5ms/step - loss: 13215679.0000 - mae: 2059.1384 - mean_absolute_percentage_error: 11.9350
# Epoch 241/250
# 31/31 - 0s - 5ms/step - loss: 10533706.0000 - mae: 1931.3037 - mean_absolute_percentage_error: 11.6272
# Epoch 242/250
# 31/31 - 0s - 5ms/step - loss: 12593305.0000 - mae: 2101.5295 - mean_absolute_percentage_error: 12.5818
# Epoch 243/250
# 31/31 - 0s - 5ms/step - loss: 11839550.0000 - mae: 2001.9094 - mean_absolute_percentage_error: 11.5010
# Epoch 244/250
# 31/31 - 0s - 5ms/step - loss: 10831149.0000 - mae: 1933.8892 - mean_absolute_percentage_error: 11.4869
# Epoch 245/250
# 31/31 - 0s - 4ms/step - loss: 12322731.0000 - mae: 2060.4749 - mean_absolute_percentage_error: 12.2963
# Epoch 246/250
# 31/31 - 0s - 5ms/step - loss: 11521255.0000 - mae: 1990.4133 - mean_absolute_percentage_error: 11.7335
# Epoch 247/250
# 31/31 - 0s - 5ms/step - loss: 12148949.0000 - mae: 2017.5756 - mean_absolute_percentage_error: 12.2244
# Epoch 248/250
# 31/31 - 0s - 5ms/step - loss: 13207214.0000 - mae: 2111.8203 - mean_absolute_percentage_error: 12.3144
# Epoch 249/250
# 31/31 - 0s - 8ms/step - loss: 12559424.0000 - mae: 2033.6923 - mean_absolute_percentage_error: 11.9286
# Epoch 250/250
# 31/31 - 0s - 5ms/step - loss: 11711370.0000 - mae: 1968.6329 - mean_absolute_percentage_error: 11.8170
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Epoch 1/250
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 31/31 - 1s - 48ms/step - loss: 443409056.0000 - mae: 15282.4492 - mean_absolute_percentage_error: 91.0618
# Epoch 2/250
# 31/31 - 0s - 4ms/step - loss: 39506244.0000 - mae: 3552.8601 - mean_absolute_percentage_error: 21.7933
# Epoch 3/250
# 31/31 - 0s - 4ms/step - loss: 12436386.0000 - mae: 1931.3458 - mean_absolute_percentage_error: 11.0540
# Epoch 4/250
# 31/31 - 0s - 5ms/step - loss: 9660698.0000 - mae: 1851.0815 - mean_absolute_percentage_error: 11.0634
# Epoch 5/250
# 31/31 - 0s - 5ms/step - loss: 10118122.0000 - mae: 1810.5026 - mean_absolute_percentage_error: 10.8432
# Epoch 6/250
# 31/31 - 0s - 5ms/step - loss: 8483287.0000 - mae: 1732.3988 - mean_absolute_percentage_error: 10.4683
# Epoch 7/250
# 31/31 - 0s - 5ms/step - loss: 10889945.0000 - mae: 1818.3992 - mean_absolute_percentage_error: 10.2753
# Epoch 8/250
# 31/31 - 0s - 5ms/step - loss: 9495108.0000 - mae: 1746.5675 - mean_absolute_percentage_error: 10.4036
# Epoch 9/250
# 31/31 - 0s - 5ms/step - loss: 9790336.0000 - mae: 1755.2986 - mean_absolute_percentage_error: 10.0103
# Epoch 10/250
# 31/31 - 0s - 5ms/step - loss: 8202508.5000 - mae: 1626.6213 - mean_absolute_percentage_error: 9.7768
# Epoch 11/250
# 31/31 - 0s - 5ms/step - loss: 7905937.5000 - mae: 1639.4633 - mean_absolute_percentage_error: 9.7506
# Epoch 12/250
# 31/31 - 0s - 5ms/step - loss: 9113362.0000 - mae: 1703.8717 - mean_absolute_percentage_error: 9.9028
# Epoch 13/250
# 31/31 - 0s - 5ms/step - loss: 7061938.5000 - mae: 1578.1826 - mean_absolute_percentage_error: 9.3545
# Epoch 14/250
# 31/31 - 0s - 5ms/step - loss: 8070395.0000 - mae: 1627.1049 - mean_absolute_percentage_error: 9.5925
# Epoch 15/250
# 31/31 - 0s - 5ms/step - loss: 10715912.0000 - mae: 1947.0398 - mean_absolute_percentage_error: 11.2482
# Epoch 16/250
# 31/31 - 0s - 5ms/step - loss: 8148957.0000 - mae: 1629.4429 - mean_absolute_percentage_error: 9.6062
# Epoch 17/250
# 31/31 - 0s - 5ms/step - loss: 8284155.5000 - mae: 1640.3403 - mean_absolute_percentage_error: 9.4036
# Epoch 18/250
# 31/31 - 0s - 5ms/step - loss: 7860371.5000 - mae: 1667.9811 - mean_absolute_percentage_error: 9.8340
# Epoch 19/250
# 31/31 - 0s - 5ms/step - loss: 6466063.0000 - mae: 1502.1162 - mean_absolute_percentage_error: 8.8055
# Epoch 20/250
# 31/31 - 0s - 5ms/step - loss: 8403474.0000 - mae: 1664.8081 - mean_absolute_percentage_error: 9.6663
# Epoch 21/250
# 31/31 - 0s - 5ms/step - loss: 6634980.0000 - mae: 1517.4175 - mean_absolute_percentage_error: 8.8562
# Epoch 22/250
# 31/31 - 0s - 5ms/step - loss: 7284456.5000 - mae: 1573.8940 - mean_absolute_percentage_error: 9.2579
# Epoch 23/250
# 31/31 - 0s - 5ms/step - loss: 7521033.5000 - mae: 1586.8661 - mean_absolute_percentage_error: 9.2797
# Epoch 24/250
# 31/31 - 0s - 5ms/step - loss: 8155128.5000 - mae: 1567.4437 - mean_absolute_percentage_error: 8.7440
# Epoch 25/250
# 31/31 - 0s - 5ms/step - loss: 7188316.0000 - mae: 1530.1807 - mean_absolute_percentage_error: 8.7250
# Epoch 26/250
# 31/31 - 0s - 7ms/step - loss: 6388253.0000 - mae: 1540.5981 - mean_absolute_percentage_error: 9.1417
# Epoch 27/250
# 31/31 - 0s - 5ms/step - loss: 4758980.0000 - mae: 1331.9655 - mean_absolute_percentage_error: 8.4198
# Epoch 28/250
# 31/31 - 0s - 5ms/step - loss: 6515540.5000 - mae: 1486.3156 - mean_absolute_percentage_error: 8.7605
# Epoch 29/250
# 31/31 - 0s - 5ms/step - loss: 5537075.0000 - mae: 1398.5281 - mean_absolute_percentage_error: 8.6697
# Epoch 30/250
# 31/31 - 0s - 5ms/step - loss: 5548527.0000 - mae: 1401.5452 - mean_absolute_percentage_error: 8.5161
# Epoch 31/250
# 31/31 - 0s - 6ms/step - loss: 6757431.0000 - mae: 1485.2150 - mean_absolute_percentage_error: 8.5179
# Epoch 32/250
# 31/31 - 0s - 5ms/step - loss: 6533549.5000 - mae: 1519.8606 - mean_absolute_percentage_error: 8.7583
# Epoch 33/250
# 31/31 - 0s - 5ms/step - loss: 5809941.5000 - mae: 1408.9321 - mean_absolute_percentage_error: 8.3889
# Epoch 34/250
# 31/31 - 0s - 5ms/step - loss: 6836342.0000 - mae: 1507.8440 - mean_absolute_percentage_error: 8.8309
# Epoch 35/250
# 31/31 - 0s - 5ms/step - loss: 7180432.0000 - mae: 1523.8960 - mean_absolute_percentage_error: 8.7401
# Epoch 36/250
# 31/31 - 0s - 5ms/step - loss: 6223090.5000 - mae: 1423.2537 - mean_absolute_percentage_error: 8.2508
# Epoch 37/250
# 31/31 - 0s - 5ms/step - loss: 5403040.0000 - mae: 1403.8892 - mean_absolute_percentage_error: 8.6591
# Epoch 38/250
# 31/31 - 0s - 5ms/step - loss: 6827999.0000 - mae: 1475.1763 - mean_absolute_percentage_error: 8.6466
# Epoch 39/250
# 31/31 - 0s - 5ms/step - loss: 9991330.0000 - mae: 1824.1677 - mean_absolute_percentage_error: 10.5282
# Epoch 40/250
# 31/31 - 0s - 5ms/step - loss: 8606845.0000 - mae: 1690.3833 - mean_absolute_percentage_error: 10.1040
# Epoch 41/250
# 31/31 - 0s - 5ms/step - loss: 8112752.5000 - mae: 1654.8693 - mean_absolute_percentage_error: 9.6603
# Epoch 42/250
# 31/31 - 0s - 5ms/step - loss: 6496944.5000 - mae: 1533.0167 - mean_absolute_percentage_error: 9.4129
# Epoch 43/250
# 31/31 - 0s - 5ms/step - loss: 9177428.0000 - mae: 1780.0225 - mean_absolute_percentage_error: 10.7095
# Epoch 44/250
# 31/31 - 0s - 5ms/step - loss: 7707939.5000 - mae: 1614.9393 - mean_absolute_percentage_error: 9.3989
# Epoch 45/250
# 31/31 - 0s - 5ms/step - loss: 7722630.0000 - mae: 1604.9786 - mean_absolute_percentage_error: 9.6723
# Epoch 46/250
# 31/31 - 0s - 5ms/step - loss: 7522289.0000 - mae: 1569.7648 - mean_absolute_percentage_error: 9.3327
# Epoch 47/250
# 31/31 - 0s - 5ms/step - loss: 7383989.0000 - mae: 1550.1168 - mean_absolute_percentage_error: 9.1521
# Epoch 48/250
# 31/31 - 0s - 5ms/step - loss: 7747448.0000 - mae: 1660.1743 - mean_absolute_percentage_error: 9.9185
# Epoch 49/250
# 31/31 - 0s - 5ms/step - loss: 6729829.5000 - mae: 1487.5411 - mean_absolute_percentage_error: 8.9347
# Epoch 50/250
# 31/31 - 0s - 5ms/step - loss: 6220249.0000 - mae: 1470.9645 - mean_absolute_percentage_error: 8.8239
# Epoch 51/250
# 31/31 - 0s - 5ms/step - loss: 8056436.0000 - mae: 1677.2435 - mean_absolute_percentage_error: 9.8121
# Epoch 52/250
# 31/31 - 0s - 5ms/step - loss: 7482711.5000 - mae: 1572.4332 - mean_absolute_percentage_error: 9.3720
# Epoch 53/250
# 31/31 - 0s - 5ms/step - loss: 7260639.5000 - mae: 1502.4418 - mean_absolute_percentage_error: 8.8032
# Epoch 54/250
# 31/31 - 0s - 5ms/step - loss: 6904105.5000 - mae: 1530.2836 - mean_absolute_percentage_error: 9.0632
# Epoch 55/250
# 31/31 - 0s - 5ms/step - loss: 7385946.5000 - mae: 1607.4700 - mean_absolute_percentage_error: 9.4828
# Epoch 56/250
# 31/31 - 0s - 5ms/step - loss: 6627246.5000 - mae: 1535.4836 - mean_absolute_percentage_error: 9.4208
# Epoch 57/250
# 31/31 - 0s - 5ms/step - loss: 7859161.5000 - mae: 1626.2517 - mean_absolute_percentage_error: 9.2713
# Epoch 58/250
# 31/31 - 0s - 5ms/step - loss: 7406544.0000 - mae: 1542.1232 - mean_absolute_percentage_error: 9.0741
# Epoch 59/250
# 31/31 - 0s - 5ms/step - loss: 8186756.5000 - mae: 1654.0360 - mean_absolute_percentage_error: 9.5719
# Epoch 60/250
# 31/31 - 0s - 5ms/step - loss: 6882599.5000 - mae: 1502.7161 - mean_absolute_percentage_error: 8.8535
# Epoch 61/250
# 31/31 - 0s - 5ms/step - loss: 6687781.0000 - mae: 1493.3817 - mean_absolute_percentage_error: 8.5796
# Epoch 62/250
# 31/31 - 0s - 5ms/step - loss: 6220893.0000 - mae: 1515.8051 - mean_absolute_percentage_error: 9.4239
# Epoch 63/250
# 31/31 - 0s - 5ms/step - loss: 6391749.5000 - mae: 1519.7982 - mean_absolute_percentage_error: 9.0905
# Epoch 64/250
# 31/31 - 0s - 5ms/step - loss: 7337698.0000 - mae: 1615.9059 - mean_absolute_percentage_error: 9.3952
# Epoch 65/250
# 31/31 - 0s - 5ms/step - loss: 6725365.5000 - mae: 1472.8840 - mean_absolute_percentage_error: 8.6598
# Epoch 66/250
# 31/31 - 0s - 5ms/step - loss: 7232057.0000 - mae: 1567.0226 - mean_absolute_percentage_error: 9.0960
# Epoch 67/250
# 31/31 - 0s - 6ms/step - loss: 7061385.0000 - mae: 1521.7220 - mean_absolute_percentage_error: 9.0702
# Epoch 68/250
# 31/31 - 0s - 5ms/step - loss: 5747560.5000 - mae: 1465.0653 - mean_absolute_percentage_error: 8.8944
# Epoch 69/250
# 31/31 - 0s - 5ms/step - loss: 6685956.0000 - mae: 1516.3303 - mean_absolute_percentage_error: 8.9091
# Epoch 70/250
# 31/31 - 0s - 5ms/step - loss: 6762397.0000 - mae: 1531.7617 - mean_absolute_percentage_error: 9.2630
# Epoch 71/250
# 31/31 - 0s - 5ms/step - loss: 6975633.0000 - mae: 1521.4240 - mean_absolute_percentage_error: 9.0559
# Epoch 72/250
# 31/31 - 0s - 5ms/step - loss: 6131652.5000 - mae: 1454.8118 - mean_absolute_percentage_error: 8.9049
# Epoch 73/250
# 31/31 - 0s - 5ms/step - loss: 6006051.5000 - mae: 1445.6947 - mean_absolute_percentage_error: 8.7090
# Epoch 74/250
# 31/31 - 0s - 5ms/step - loss: 7778422.5000 - mae: 1600.8280 - mean_absolute_percentage_error: 9.1957
# Epoch 75/250
# 31/31 - 0s - 5ms/step - loss: 7141784.0000 - mae: 1599.1720 - mean_absolute_percentage_error: 9.7730
# Epoch 76/250
# 31/31 - 0s - 5ms/step - loss: 7579795.5000 - mae: 1543.2279 - mean_absolute_percentage_error: 9.1956
# Epoch 77/250
# 31/31 - 0s - 5ms/step - loss: 8343027.0000 - mae: 1622.4482 - mean_absolute_percentage_error: 9.0804
# Epoch 78/250
# 31/31 - 0s - 5ms/step - loss: 9512013.0000 - mae: 1797.2362 - mean_absolute_percentage_error: 10.2990
# Epoch 79/250
# 31/31 - 0s - 5ms/step - loss: 8267834.5000 - mae: 1655.9636 - mean_absolute_percentage_error: 9.8330
# Epoch 80/250
# 31/31 - 0s - 5ms/step - loss: 6649503.5000 - mae: 1471.7294 - mean_absolute_percentage_error: 8.5798
# Epoch 81/250
# 31/31 - 0s - 5ms/step - loss: 6130793.5000 - mae: 1436.8324 - mean_absolute_percentage_error: 8.5320
# Epoch 82/250
# 31/31 - 0s - 5ms/step - loss: 6688219.5000 - mae: 1456.3181 - mean_absolute_percentage_error: 8.3876
# Epoch 83/250
# 31/31 - 0s - 5ms/step - loss: 6319214.0000 - mae: 1476.4146 - mean_absolute_percentage_error: 9.0061
# Epoch 84/250
# 31/31 - 0s - 5ms/step - loss: 7821515.5000 - mae: 1559.6771 - mean_absolute_percentage_error: 8.9832
# Epoch 85/250
# 31/31 - 0s - 5ms/step - loss: 8170795.5000 - mae: 1670.3491 - mean_absolute_percentage_error: 9.9327
# Epoch 86/250
# 31/31 - 0s - 5ms/step - loss: 7758172.0000 - mae: 1612.5302 - mean_absolute_percentage_error: 9.6517
# Epoch 87/250
# 31/31 - 0s - 5ms/step - loss: 6044787.0000 - mae: 1493.6919 - mean_absolute_percentage_error: 8.9287
# Epoch 88/250
# 31/31 - 0s - 5ms/step - loss: 6035707.0000 - mae: 1454.5896 - mean_absolute_percentage_error: 8.7797
# Epoch 89/250
# 31/31 - 0s - 5ms/step - loss: 8501677.0000 - mae: 1638.8086 - mean_absolute_percentage_error: 9.2707
# Epoch 90/250
# 31/31 - 0s - 6ms/step - loss: 6930741.0000 - mae: 1551.1891 - mean_absolute_percentage_error: 9.5023
# Epoch 91/250
# 31/31 - 0s - 5ms/step - loss: 5952384.5000 - mae: 1461.9183 - mean_absolute_percentage_error: 8.7670
# Epoch 92/250
# 31/31 - 0s - 5ms/step - loss: 6165647.0000 - mae: 1430.9962 - mean_absolute_percentage_error: 8.4527
# Epoch 93/250
# 31/31 - 0s - 5ms/step - loss: 6676939.5000 - mae: 1511.7679 - mean_absolute_percentage_error: 8.6825
# Epoch 94/250
# 31/31 - 0s - 5ms/step - loss: 6129184.5000 - mae: 1450.4106 - mean_absolute_percentage_error: 8.6957
# Epoch 95/250
# 31/31 - 0s - 5ms/step - loss: 6500477.5000 - mae: 1485.6708 - mean_absolute_percentage_error: 8.7634
# Epoch 96/250
# 31/31 - 0s - 5ms/step - loss: 6396827.5000 - mae: 1483.5382 - mean_absolute_percentage_error: 8.7826
# Epoch 97/250
# 31/31 - 0s - 5ms/step - loss: 6276945.5000 - mae: 1443.3794 - mean_absolute_percentage_error: 8.5989
# Epoch 98/250
# 31/31 - 0s - 5ms/step - loss: 5900652.0000 - mae: 1424.3867 - mean_absolute_percentage_error: 8.4512
# Epoch 99/250
# 31/31 - 0s - 5ms/step - loss: 5925515.5000 - mae: 1418.4321 - mean_absolute_percentage_error: 8.3265
# Epoch 100/250
# 31/31 - 0s - 5ms/step - loss: 7514932.0000 - mae: 1577.4713 - mean_absolute_percentage_error: 9.1986
# Epoch 101/250
# 31/31 - 0s - 5ms/step - loss: 7526943.0000 - mae: 1541.6224 - mean_absolute_percentage_error: 8.6971
# Epoch 102/250
# 31/31 - 0s - 5ms/step - loss: 5380456.0000 - mae: 1388.9391 - mean_absolute_percentage_error: 8.3439
# Epoch 103/250
# 31/31 - 0s - 5ms/step - loss: 7210045.5000 - mae: 1607.4265 - mean_absolute_percentage_error: 9.6140
# Epoch 104/250
# 31/31 - 0s - 5ms/step - loss: 7800993.5000 - mae: 1571.2811 - mean_absolute_percentage_error: 8.8130
# Epoch 105/250
# 31/31 - 0s - 5ms/step - loss: 6085811.0000 - mae: 1495.1400 - mean_absolute_percentage_error: 8.9328
# Epoch 106/250
# 31/31 - 0s - 5ms/step - loss: 6349297.0000 - mae: 1515.0098 - mean_absolute_percentage_error: 9.2865
# Epoch 107/250
# 31/31 - 0s - 5ms/step - loss: 6981356.5000 - mae: 1537.3860 - mean_absolute_percentage_error: 8.8927
# Epoch 108/250
# 31/31 - 0s - 6ms/step - loss: 5459490.0000 - mae: 1379.9371 - mean_absolute_percentage_error: 8.3848
# Epoch 109/250
# 31/31 - 0s - 5ms/step - loss: 5844881.0000 - mae: 1479.0039 - mean_absolute_percentage_error: 9.1480
# Epoch 110/250
# 31/31 - 0s - 5ms/step - loss: 7044350.0000 - mae: 1516.4395 - mean_absolute_percentage_error: 8.6669
# Epoch 111/250
# 31/31 - 0s - 5ms/step - loss: 6475642.0000 - mae: 1506.2247 - mean_absolute_percentage_error: 9.1146
# Epoch 112/250
# 31/31 - 0s - 5ms/step - loss: 8329473.0000 - mae: 1690.8802 - mean_absolute_percentage_error: 9.7905
# Epoch 113/250
# 31/31 - 0s - 5ms/step - loss: 7040443.0000 - mae: 1581.8511 - mean_absolute_percentage_error: 9.5062
# Epoch 114/250
# 31/31 - 0s - 4ms/step - loss: 7080338.0000 - mae: 1521.4481 - mean_absolute_percentage_error: 8.8664
# Epoch 115/250
# 31/31 - 0s - 5ms/step - loss: 6350219.5000 - mae: 1519.2485 - mean_absolute_percentage_error: 8.9496
# Epoch 116/250
# 31/31 - 0s - 5ms/step - loss: 7875863.5000 - mae: 1642.0840 - mean_absolute_percentage_error: 9.9118
# Epoch 117/250
# 31/31 - 0s - 5ms/step - loss: 6839601.0000 - mae: 1512.0321 - mean_absolute_percentage_error: 8.7777
# Epoch 118/250
# 31/31 - 0s - 5ms/step - loss: 7288707.5000 - mae: 1544.3054 - mean_absolute_percentage_error: 9.0614
# Epoch 119/250
# 31/31 - 0s - 5ms/step - loss: 7929335.0000 - mae: 1661.1993 - mean_absolute_percentage_error: 9.6652
# Epoch 120/250
# 31/31 - 0s - 5ms/step - loss: 6362289.5000 - mae: 1479.0726 - mean_absolute_percentage_error: 8.9067
# Epoch 121/250
# 31/31 - 0s - 5ms/step - loss: 6080971.0000 - mae: 1467.5391 - mean_absolute_percentage_error: 9.1885
# Epoch 122/250
# 31/31 - 0s - 5ms/step - loss: 7287054.0000 - mae: 1556.8170 - mean_absolute_percentage_error: 9.0533
# Epoch 123/250
# 31/31 - 0s - 5ms/step - loss: 6882468.0000 - mae: 1517.6262 - mean_absolute_percentage_error: 9.2049
# Epoch 124/250
# 31/31 - 0s - 5ms/step - loss: 6791941.5000 - mae: 1535.9558 - mean_absolute_percentage_error: 8.9393
# Epoch 125/250
# 31/31 - 0s - 5ms/step - loss: 6548022.0000 - mae: 1472.6360 - mean_absolute_percentage_error: 8.6862
# Epoch 126/250
# 31/31 - 0s - 5ms/step - loss: 6694237.5000 - mae: 1515.3345 - mean_absolute_percentage_error: 8.9421
# Epoch 127/250
# 31/31 - 0s - 5ms/step - loss: 7582578.5000 - mae: 1593.8318 - mean_absolute_percentage_error: 9.6213
# Epoch 128/250
# 31/31 - 0s - 5ms/step - loss: 8215030.0000 - mae: 1616.8633 - mean_absolute_percentage_error: 9.4827
# Epoch 129/250
# 31/31 - 0s - 5ms/step - loss: 14058729.0000 - mae: 2159.1985 - mean_absolute_percentage_error: 12.7860
# Epoch 130/250
# 31/31 - 0s - 5ms/step - loss: 15656348.0000 - mae: 2344.9558 - mean_absolute_percentage_error: 14.0818
# Epoch 131/250
# 31/31 - 0s - 5ms/step - loss: 15378911.0000 - mae: 2244.2883 - mean_absolute_percentage_error: 13.0867
# Epoch 132/250
# 31/31 - 0s - 5ms/step - loss: 13029311.0000 - mae: 2039.6776 - mean_absolute_percentage_error: 11.8819
# Epoch 133/250
# 31/31 - 0s - 5ms/step - loss: 19034412.0000 - mae: 2490.7981 - mean_absolute_percentage_error: 14.1995
# Epoch 134/250
# 31/31 - 0s - 5ms/step - loss: 10943572.0000 - mae: 1847.5886 - mean_absolute_percentage_error: 10.5803
# Epoch 135/250
# 31/31 - 0s - 5ms/step - loss: 10890150.0000 - mae: 1999.5089 - mean_absolute_percentage_error: 11.9133
# Epoch 136/250
# 31/31 - 0s - 5ms/step - loss: 9565929.0000 - mae: 1784.9818 - mean_absolute_percentage_error: 10.5855
# Epoch 137/250
# 31/31 - 0s - 5ms/step - loss: 9723390.0000 - mae: 1810.7330 - mean_absolute_percentage_error: 10.5149
# Epoch 138/250
# 31/31 - 0s - 5ms/step - loss: 9326204.0000 - mae: 1784.2198 - mean_absolute_percentage_error: 10.6868
# Epoch 139/250
# 31/31 - 0s - 5ms/step - loss: 9885438.0000 - mae: 1786.7301 - mean_absolute_percentage_error: 10.3564
# Epoch 140/250
# 31/31 - 0s - 5ms/step - loss: 9689389.0000 - mae: 1784.3413 - mean_absolute_percentage_error: 10.4533
# Epoch 141/250
# 31/31 - 0s - 5ms/step - loss: 9190449.0000 - mae: 1772.8124 - mean_absolute_percentage_error: 10.3322
# Epoch 142/250
# 31/31 - 0s - 5ms/step - loss: 8966959.0000 - mae: 1715.3308 - mean_absolute_percentage_error: 10.2541
# Epoch 143/250
# 31/31 - 0s - 5ms/step - loss: 8583429.0000 - mae: 1679.0424 - mean_absolute_percentage_error: 10.0092
# Epoch 144/250
# 31/31 - 0s - 5ms/step - loss: 9367549.0000 - mae: 1799.8209 - mean_absolute_percentage_error: 10.5008
# Epoch 145/250
# 31/31 - 0s - 5ms/step - loss: 10074501.0000 - mae: 1847.3243 - mean_absolute_percentage_error: 10.7144
# Epoch 146/250
# 31/31 - 0s - 5ms/step - loss: 9003660.0000 - mae: 1788.5111 - mean_absolute_percentage_error: 10.7131
# Epoch 147/250
# 31/31 - 0s - 5ms/step - loss: 9085480.0000 - mae: 1737.7592 - mean_absolute_percentage_error: 10.4070
# Epoch 148/250
# 31/31 - 0s - 6ms/step - loss: 9386049.0000 - mae: 1742.3737 - mean_absolute_percentage_error: 9.8583
# Epoch 149/250
# 31/31 - 0s - 5ms/step - loss: 9787596.0000 - mae: 1817.7517 - mean_absolute_percentage_error: 10.6453
# Epoch 150/250
# 31/31 - 0s - 5ms/step - loss: 7471149.5000 - mae: 1667.8599 - mean_absolute_percentage_error: 10.2040
# Epoch 151/250
# 31/31 - 0s - 5ms/step - loss: 9206984.0000 - mae: 1772.2462 - mean_absolute_percentage_error: 10.5181
# Epoch 152/250
# 31/31 - 0s - 5ms/step - loss: 9828060.0000 - mae: 1791.6552 - mean_absolute_percentage_error: 10.5228
# Epoch 153/250
# 31/31 - 0s - 5ms/step - loss: 8509989.0000 - mae: 1676.2562 - mean_absolute_percentage_error: 9.9256
# Epoch 154/250
# 31/31 - 0s - 5ms/step - loss: 8882584.0000 - mae: 1734.7323 - mean_absolute_percentage_error: 10.2432
# Epoch 155/250
# 31/31 - 0s - 5ms/step - loss: 9527522.0000 - mae: 1793.2190 - mean_absolute_percentage_error: 10.8325
# Epoch 156/250
# 31/31 - 0s - 5ms/step - loss: 8293651.0000 - mae: 1742.6881 - mean_absolute_percentage_error: 10.2689
# Epoch 157/250
# 31/31 - 0s - 5ms/step - loss: 9586928.0000 - mae: 1855.4045 - mean_absolute_percentage_error: 10.8781
# Epoch 158/250
# 31/31 - 0s - 5ms/step - loss: 8012840.0000 - mae: 1658.7174 - mean_absolute_percentage_error: 9.8015
# Epoch 159/250
# 31/31 - 0s - 5ms/step - loss: 7348050.0000 - mae: 1631.4097 - mean_absolute_percentage_error: 9.8698
# Epoch 160/250
# 31/31 - 0s - 5ms/step - loss: 7781218.5000 - mae: 1613.5165 - mean_absolute_percentage_error: 9.5670
# Epoch 161/250
# 31/31 - 0s - 5ms/step - loss: 8450676.0000 - mae: 1651.9462 - mean_absolute_percentage_error: 9.9155
# Epoch 162/250
# 31/31 - 0s - 5ms/step - loss: 8465248.0000 - mae: 1739.0057 - mean_absolute_percentage_error: 10.1842
# Epoch 163/250
# ...
# Epoch 116/250
# 31/31 - 0s - 5ms/step - loss: 5197720.0000 - mae: 1335.0156 - mean_absolute_percentage_error: 7.9278
# Epoch 117/250
# 31/31 - 0s - 5ms/step - loss: 6976506.5000 - mae: 1550.2167 - mean_absolute_percentage_error: 8.9417
# Epoch 118/250
# 31/31 - 0s - 5ms/step - loss: 9015702.0000 - mae: 1764.7745 - mean_absolute_percentage_error: 10.3881
# Epoch 119/250
# 31/31 - 0s - 5ms/step - loss: 6686382.5000 - mae: 1502.1392 - mean_absolute_percentage_error: 8.5975
# Epoch 120/250
# 31/31 - 0s - 5ms/step - loss: 6194059.5000 - mae: 1475.6036 - mean_absolute_percentage_error: 8.7207
# Epoch 121/250
# 31/31 - 0s - 5ms/step - loss: 6361925.0000 - mae: 1456.0587 - mean_absolute_percentage_error: 8.3269
# Epoch 122/250
# 31/31 - 0s - 5ms/step - loss: 5007377.0000 - mae: 1334.9991 - mean_absolute_percentage_error: 8.1301
# Epoch 123/250
# 31/31 - 0s - 5ms/step - loss: 6715401.0000 - mae: 1485.5309 - mean_absolute_percentage_error: 8.6539
# Epoch 124/250
# 31/31 - 0s - 6ms/step - loss: 5275742.5000 - mae: 1294.6664 - mean_absolute_percentage_error: 7.5281
# Epoch 125/250
# 31/31 - 0s - 5ms/step - loss: 6362487.5000 - mae: 1489.5807 - mean_absolute_percentage_error: 8.8242
# Epoch 126/250
# 31/31 - 0s - 5ms/step - loss: 5884484.5000 - mae: 1395.7748 - mean_absolute_percentage_error: 8.0752
# Epoch 127/250
# 31/31 - 0s - 5ms/step - loss: 6451102.0000 - mae: 1419.3563 - mean_absolute_percentage_error: 8.2894
# Epoch 128/250
# 31/31 - 0s - 5ms/step - loss: 5432110.0000 - mae: 1365.0566 - mean_absolute_percentage_error: 8.0926
# Epoch 129/250
# 31/31 - 0s - 5ms/step - loss: 5990691.5000 - mae: 1460.9467 - mean_absolute_percentage_error: 8.5803
# Epoch 130/250
# 31/31 - 0s - 5ms/step - loss: 7080169.5000 - mae: 1535.3057 - mean_absolute_percentage_error: 9.1170
# Epoch 131/250
# 31/31 - 0s - 5ms/step - loss: 7214906.0000 - mae: 1551.5509 - mean_absolute_percentage_error: 9.0134
# Epoch 132/250
# 31/31 - 0s - 5ms/step - loss: 7747597.0000 - mae: 1560.5203 - mean_absolute_percentage_error: 8.9178
# Epoch 133/250
# 31/31 - 0s - 5ms/step - loss: 6277454.5000 - mae: 1466.0676 - mean_absolute_percentage_error: 8.7352
# Epoch 134/250
# 31/31 - 0s - 5ms/step - loss: 6022656.5000 - mae: 1442.1600 - mean_absolute_percentage_error: 8.4733
# Epoch 135/250
# 31/31 - 0s - 5ms/step - loss: 5458146.5000 - mae: 1374.1495 - mean_absolute_percentage_error: 8.2557
# Epoch 136/250
# 31/31 - 0s - 5ms/step - loss: 6368549.5000 - mae: 1411.9348 - mean_absolute_percentage_error: 8.1401
# Epoch 137/250
# 31/31 - 0s - 5ms/step - loss: 12211441.0000 - mae: 1981.8381 - mean_absolute_percentage_error: 11.6906
# Epoch 138/250
# 31/31 - 0s - 5ms/step - loss: 13598162.0000 - mae: 2198.6204 - mean_absolute_percentage_error: 12.9583
# Epoch 139/250
# 31/31 - 0s - 5ms/step - loss: 10583109.0000 - mae: 1932.6821 - mean_absolute_percentage_error: 11.9442
# Epoch 140/250
# 31/31 - 0s - 5ms/step - loss: 10821525.0000 - mae: 1977.8406 - mean_absolute_percentage_error: 11.7329
# Epoch 141/250
# 31/31 - 0s - 5ms/step - loss: 8890411.0000 - mae: 1813.6681 - mean_absolute_percentage_error: 10.8904
# Epoch 142/250
# 31/31 - 0s - 5ms/step - loss: 11281273.0000 - mae: 1893.7976 - mean_absolute_percentage_error: 11.2033
# Epoch 143/250
# 31/31 - 0s - 6ms/step - loss: 8906346.0000 - mae: 1690.3236 - mean_absolute_percentage_error: 10.0391
# Epoch 144/250
# 31/31 - 0s - 7ms/step - loss: 8127678.5000 - mae: 1750.2352 - mean_absolute_percentage_error: 10.8874
# Epoch 145/250
# 31/31 - 0s - 5ms/step - loss: 9540625.0000 - mae: 1816.7058 - mean_absolute_percentage_error: 10.8480
# Epoch 146/250
# 31/31 - 0s - 5ms/step - loss: 11364098.0000 - mae: 1881.1785 - mean_absolute_percentage_error: 10.8017
# Epoch 147/250
# 31/31 - 0s - 5ms/step - loss: 10054142.0000 - mae: 1869.9165 - mean_absolute_percentage_error: 11.1825
# Epoch 148/250
# 31/31 - 0s - 5ms/step - loss: 10877467.0000 - mae: 1840.4397 - mean_absolute_percentage_error: 10.5412
# Epoch 149/250
# 31/31 - 0s - 5ms/step - loss: 9694858.0000 - mae: 1798.0520 - mean_absolute_percentage_error: 10.4305
# Epoch 150/250
# 31/31 - 0s - 5ms/step - loss: 9960677.0000 - mae: 1791.2692 - mean_absolute_percentage_error: 10.3776
# Epoch 151/250
# 31/31 - 0s - 5ms/step - loss: 10620542.0000 - mae: 1874.1245 - mean_absolute_percentage_error: 11.0782
# Epoch 152/250
# 31/31 - 0s - 5ms/step - loss: 10725642.0000 - mae: 1936.1130 - mean_absolute_percentage_error: 11.4004
# Epoch 153/250
# 31/31 - 0s - 5ms/step - loss: 9115613.0000 - mae: 1811.2731 - mean_absolute_percentage_error: 10.8181
# Epoch 154/250
# 31/31 - 0s - 5ms/step - loss: 8780940.0000 - mae: 1750.4062 - mean_absolute_percentage_error: 10.5466
# Epoch 155/250
# 31/31 - 0s - 5ms/step - loss: 9708340.0000 - mae: 1813.4224 - mean_absolute_percentage_error: 10.6305
# Epoch 156/250
# 31/31 - 0s - 5ms/step - loss: 9276976.0000 - mae: 1809.3578 - mean_absolute_percentage_error: 10.5214
# Epoch 157/250
# 31/31 - 0s - 5ms/step - loss: 8168685.5000 - mae: 1678.7006 - mean_absolute_percentage_error: 10.1618
# Epoch 158/250
# 31/31 - 0s - 5ms/step - loss: 9189039.0000 - mae: 1791.6107 - mean_absolute_percentage_error: 10.9860
# Epoch 159/250
# 31/31 - 0s - 5ms/step - loss: 7847269.5000 - mae: 1674.5001 - mean_absolute_percentage_error: 10.3621
# Epoch 160/250
# 31/31 - 0s - 5ms/step - loss: 9028560.0000 - mae: 1741.6461 - mean_absolute_percentage_error: 10.8139
# Epoch 161/250
# 31/31 - 0s - 5ms/step - loss: 9899655.0000 - mae: 1780.4551 - mean_absolute_percentage_error: 10.1801
# Epoch 162/250
# 31/31 - 0s - 5ms/step - loss: 9087051.0000 - mae: 1768.3683 - mean_absolute_percentage_error: 10.5098
# Epoch 163/250
# 31/31 - 0s - 5ms/step - loss: 10114428.0000 - mae: 1827.9393 - mean_absolute_percentage_error: 10.3434
# Epoch 164/250
# 31/31 - 0s - 5ms/step - loss: 8819176.0000 - mae: 1687.9424 - mean_absolute_percentage_error: 9.8548
# Epoch 165/250
# 31/31 - 0s - 7ms/step - loss: 7668482.0000 - mae: 1654.7184 - mean_absolute_percentage_error: 10.0317
# Epoch 166/250
# 31/31 - 0s - 5ms/step - loss: 8773964.0000 - mae: 1738.1720 - mean_absolute_percentage_error: 10.0611
# Epoch 167/250
# 31/31 - 0s - 5ms/step - loss: 8525168.0000 - mae: 1714.7026 - mean_absolute_percentage_error: 10.0546
# Epoch 168/250
# 31/31 - 0s - 5ms/step - loss: 9065534.0000 - mae: 1747.5063 - mean_absolute_percentage_error: 10.2567
# Epoch 169/250
# 31/31 - 0s - 5ms/step - loss: 10414291.0000 - mae: 1888.1757 - mean_absolute_percentage_error: 11.2826
# Epoch 170/250
# 31/31 - 0s - 5ms/step - loss: 12452936.0000 - mae: 2006.0221 - mean_absolute_percentage_error: 11.4356
# Epoch 171/250
# 31/31 - 0s - 5ms/step - loss: 10398538.0000 - mae: 1902.2297 - mean_absolute_percentage_error: 11.4804
# Epoch 172/250
# 31/31 - 0s - 5ms/step - loss: 8197139.0000 - mae: 1760.0116 - mean_absolute_percentage_error: 10.7907
# Epoch 173/250
# 31/31 - 0s - 5ms/step - loss: 9270361.0000 - mae: 1775.1842 - mean_absolute_percentage_error: 10.4791
# Epoch 174/250
# 31/31 - 0s - 5ms/step - loss: 9735807.0000 - mae: 1882.8569 - mean_absolute_percentage_error: 11.0616
# Epoch 175/250
# 31/31 - 0s - 5ms/step - loss: 9856313.0000 - mae: 1827.7302 - mean_absolute_percentage_error: 10.7936
# Epoch 176/250
# 31/31 - 0s - 5ms/step - loss: 9689536.0000 - mae: 1873.5073 - mean_absolute_percentage_error: 11.1654
# Epoch 177/250
# 31/31 - 0s - 5ms/step - loss: 9701347.0000 - mae: 1820.0515 - mean_absolute_percentage_error: 10.7476
# Epoch 178/250
# 31/31 - 0s - 5ms/step - loss: 9659550.0000 - mae: 1756.3051 - mean_absolute_percentage_error: 10.4755
# Epoch 179/250
# 31/31 - 0s - 5ms/step - loss: 11003356.0000 - mae: 1888.8234 - mean_absolute_percentage_error: 10.7992
# Epoch 180/250
# 31/31 - 0s - 5ms/step - loss: 10202791.0000 - mae: 1787.2889 - mean_absolute_percentage_error: 10.1795
# Epoch 181/250
# 31/31 - 0s - 5ms/step - loss: 10243062.0000 - mae: 1874.2732 - mean_absolute_percentage_error: 10.8666
# Epoch 182/250
# 31/31 - 0s - 5ms/step - loss: 10109830.0000 - mae: 1783.9966 - mean_absolute_percentage_error: 10.3725
# Epoch 183/250
# 31/31 - 0s - 5ms/step - loss: 9475113.0000 - mae: 1754.7063 - mean_absolute_percentage_error: 10.3902
# Epoch 184/250
# 31/31 - 0s - 5ms/step - loss: 8526671.0000 - mae: 1733.0917 - mean_absolute_percentage_error: 10.3431
# Epoch 185/250
# 31/31 - 0s - 5ms/step - loss: 10244740.0000 - mae: 1855.0492 - mean_absolute_percentage_error: 10.7814
# Epoch 186/250
# 31/31 - 0s - 5ms/step - loss: 10179035.0000 - mae: 1861.6869 - mean_absolute_percentage_error: 10.7474
# Epoch 187/250
# 31/31 - 0s - 5ms/step - loss: 9708078.0000 - mae: 1825.0116 - mean_absolute_percentage_error: 10.7853
# Epoch 188/250
# 31/31 - 0s - 5ms/step - loss: 9002862.0000 - mae: 1768.7621 - mean_absolute_percentage_error: 10.4349
# Epoch 189/250
# 31/31 - 0s - 5ms/step - loss: 10092763.0000 - mae: 1803.3319 - mean_absolute_percentage_error: 10.3469
# Epoch 190/250
# 31/31 - 0s - 5ms/step - loss: 10914435.0000 - mae: 1888.0526 - mean_absolute_percentage_error: 10.7914
# Epoch 191/250
# 31/31 - 0s - 5ms/step - loss: 10042764.0000 - mae: 1783.1801 - mean_absolute_percentage_error: 10.4584
# Epoch 192/250
# 31/31 - 0s - 5ms/step - loss: 7665962.5000 - mae: 1695.1024 - mean_absolute_percentage_error: 10.5790
# Epoch 193/250
# 31/31 - 0s - 5ms/step - loss: 9323275.0000 - mae: 1831.3864 - mean_absolute_percentage_error: 10.9795
# Epoch 194/250
# 31/31 - 0s - 5ms/step - loss: 10623864.0000 - mae: 1880.3612 - mean_absolute_percentage_error: 10.9530
# Epoch 195/250
# 31/31 - 0s - 5ms/step - loss: 10757005.0000 - mae: 1899.9740 - mean_absolute_percentage_error: 11.3040
# Epoch 196/250
# 31/31 - 0s - 5ms/step - loss: 10035134.0000 - mae: 1821.3735 - mean_absolute_percentage_error: 10.6486
# Epoch 197/250
# 31/31 - 0s - 5ms/step - loss: 9514617.0000 - mae: 1834.8352 - mean_absolute_percentage_error: 11.0427
# Epoch 198/250
# 31/31 - 0s - 7ms/step - loss: 9568658.0000 - mae: 1824.0477 - mean_absolute_percentage_error: 10.8107
# Epoch 199/250
# 31/31 - 0s - 6ms/step - loss: 9995705.0000 - mae: 1865.9973 - mean_absolute_percentage_error: 11.0561
# Epoch 200/250
# 31/31 - 0s - 5ms/step - loss: 9064713.0000 - mae: 1763.5895 - mean_absolute_percentage_error: 10.6339
# Epoch 201/250
# 31/31 - 0s - 5ms/step - loss: 10676363.0000 - mae: 1814.9850 - mean_absolute_percentage_error: 10.6672
# Epoch 202/250
# 31/31 - 0s - 5ms/step - loss: 9272537.0000 - mae: 1687.5182 - mean_absolute_percentage_error: 10.0261
# Epoch 203/250
# 31/31 - 0s - 5ms/step - loss: 8542037.0000 - mae: 1708.8734 - mean_absolute_percentage_error: 9.9355
# Epoch 204/250
# 31/31 - 0s - 7ms/step - loss: 11296970.0000 - mae: 2008.3560 - mean_absolute_percentage_error: 11.7984
# Epoch 205/250
# 31/31 - 0s - 5ms/step - loss: 11947806.0000 - mae: 1882.4890 - mean_absolute_percentage_error: 10.7085
# Epoch 206/250
# 31/31 - 0s - 5ms/step - loss: 9160700.0000 - mae: 1747.5887 - mean_absolute_percentage_error: 10.6013
# Epoch 207/250
# 31/31 - 0s - 5ms/step - loss: 9381470.0000 - mae: 1797.7645 - mean_absolute_percentage_error: 10.7711
# Epoch 208/250
# 31/31 - 0s - 5ms/step - loss: 10312300.0000 - mae: 1830.6268 - mean_absolute_percentage_error: 10.4603
# Epoch 209/250
# 31/31 - 0s - 5ms/step - loss: 9106203.0000 - mae: 1783.2701 - mean_absolute_percentage_error: 10.7832
# Epoch 210/250
# 31/31 - 0s - 5ms/step - loss: 11175570.0000 - mae: 1888.4111 - mean_absolute_percentage_error: 10.7196
# Epoch 211/250
# 31/31 - 0s - 5ms/step - loss: 8563889.0000 - mae: 1733.7456 - mean_absolute_percentage_error: 10.4875
# Epoch 212/250
# 31/31 - 0s - 5ms/step - loss: 9070558.0000 - mae: 1781.6984 - mean_absolute_percentage_error: 10.4703
# Epoch 213/250
# 31/31 - 0s - 5ms/step - loss: 8184827.0000 - mae: 1702.1331 - mean_absolute_percentage_error: 10.1227
# Epoch 214/250
# 31/31 - 0s - 5ms/step - loss: 9588307.0000 - mae: 1776.1290 - mean_absolute_percentage_error: 10.2805
# Epoch 215/250
# 31/31 - 0s - 5ms/step - loss: 8999977.0000 - mae: 1762.2169 - mean_absolute_percentage_error: 10.6618
# Epoch 216/250
# 31/31 - 0s - 5ms/step - loss: 8932251.0000 - mae: 1742.9708 - mean_absolute_percentage_error: 10.6769
# Epoch 217/250
# 31/31 - 0s - 5ms/step - loss: 8956491.0000 - mae: 1695.3357 - mean_absolute_percentage_error: 9.9804
# Epoch 218/250
# 31/31 - 0s - 5ms/step - loss: 10762673.0000 - mae: 1835.9127 - mean_absolute_percentage_error: 10.5317
# Epoch 219/250
# 31/31 - 0s - 5ms/step - loss: 10040339.0000 - mae: 1814.2128 - mean_absolute_percentage_error: 10.7227
# Epoch 220/250
# 31/31 - 0s - 5ms/step - loss: 7677553.0000 - mae: 1639.2181 - mean_absolute_percentage_error: 9.8944
# Epoch 221/250
# 31/31 - 0s - 5ms/step - loss: 8178028.5000 - mae: 1689.4287 - mean_absolute_percentage_error: 10.1789
# Epoch 222/250
# 31/31 - 0s - 5ms/step - loss: 10505335.0000 - mae: 1889.0597 - mean_absolute_percentage_error: 11.0131
# Epoch 223/250
# 31/31 - 0s - 5ms/step - loss: 9445321.0000 - mae: 1798.6022 - mean_absolute_percentage_error: 10.8959
# Epoch 224/250
# 31/31 - 0s - 5ms/step - loss: 9582652.0000 - mae: 1775.8629 - mean_absolute_percentage_error: 10.5017
# Epoch 225/250
# 31/31 - 0s - 5ms/step - loss: 9496737.0000 - mae: 1796.6703 - mean_absolute_percentage_error: 10.8552
# Epoch 226/250
# 31/31 - 0s - 5ms/step - loss: 10710835.0000 - mae: 1890.6160 - mean_absolute_percentage_error: 11.0930
# Epoch 227/250
# 31/31 - 0s - 5ms/step - loss: 9666889.0000 - mae: 1819.5566 - mean_absolute_percentage_error: 10.8721
# Epoch 228/250
# 31/31 - 0s - 5ms/step - loss: 11612751.0000 - mae: 1915.9927 - mean_absolute_percentage_error: 10.5973
# Epoch 229/250
# 31/31 - 0s - 5ms/step - loss: 11556125.0000 - mae: 1934.9062 - mean_absolute_percentage_error: 11.4269
# Epoch 230/250
# 31/31 - 0s - 5ms/step - loss: 9970195.0000 - mae: 1806.7148 - mean_absolute_percentage_error: 10.8885
# Epoch 231/250
# 31/31 - 0s - 5ms/step - loss: 11538133.0000 - mae: 1930.4215 - mean_absolute_percentage_error: 11.3434
# Epoch 232/250
# 31/31 - 0s - 5ms/step - loss: 11093212.0000 - mae: 1897.2966 - mean_absolute_percentage_error: 11.2616
# Epoch 233/250
# 31/31 - 0s - 5ms/step - loss: 10028004.0000 - mae: 1853.6790 - mean_absolute_percentage_error: 10.9750
# Epoch 234/250
# 31/31 - 0s - 5ms/step - loss: 7370721.0000 - mae: 1648.3892 - mean_absolute_percentage_error: 10.1512
# Epoch 235/250
# 31/31 - 0s - 5ms/step - loss: 8616775.0000 - mae: 1739.5156 - mean_absolute_percentage_error: 10.6402
# Epoch 236/250
# 31/31 - 0s - 5ms/step - loss: 8670011.0000 - mae: 1738.7645 - mean_absolute_percentage_error: 10.2931
# Epoch 237/250
# 31/31 - 0s - 5ms/step - loss: 10910893.0000 - mae: 1857.0934 - mean_absolute_percentage_error: 10.7278
# Epoch 238/250
# 31/31 - 0s - 5ms/step - loss: 9413192.0000 - mae: 1768.5883 - mean_absolute_percentage_error: 10.5152
# Epoch 239/250
# 31/31 - 0s - 5ms/step - loss: 8730696.0000 - mae: 1774.9338 - mean_absolute_percentage_error: 10.5909
# Epoch 240/250
# 31/31 - 0s - 5ms/step - loss: 7833489.5000 - mae: 1675.3003 - mean_absolute_percentage_error: 10.1439
# Epoch 241/250
# 31/31 - 0s - 5ms/step - loss: 9735471.0000 - mae: 1762.3733 - mean_absolute_percentage_error: 10.3661
# Epoch 242/250
# 31/31 - 0s - 5ms/step - loss: 8405100.0000 - mae: 1686.3610 - mean_absolute_percentage_error: 10.2604
# Epoch 243/250
# 31/31 - 0s - 9ms/step - loss: 11295048.0000 - mae: 1901.2146 - mean_absolute_percentage_error: 10.7847
# Epoch 244/250
# 31/31 - 0s - 5ms/step - loss: 11333738.0000 - mae: 1976.1910 - mean_absolute_percentage_error: 11.5558
# Epoch 245/250
# 31/31 - 0s - 5ms/step - loss: 11380758.0000 - mae: 1938.1150 - mean_absolute_percentage_error: 11.0494
# Epoch 246/250
# 31/31 - 0s - 5ms/step - loss: 9880892.0000 - mae: 1767.2195 - mean_absolute_percentage_error: 10.4714
# Epoch 247/250
# 31/31 - 0s - 5ms/step - loss: 9783088.0000 - mae: 1810.3607 - mean_absolute_percentage_error: 10.5166
# Epoch 248/250
# 31/31 - 0s - 5ms/step - loss: 8292509.5000 - mae: 1732.9061 - mean_absolute_percentage_error: 10.5733
# Epoch 249/250
# 31/31 - 0s - 5ms/step - loss: 10117621.0000 - mae: 1776.1774 - mean_absolute_percentage_error: 10.5117
# Epoch 250/250
# 31/31 - 0s - 5ms/step - loss: 10145149.0000 - mae: 1806.3107 - mean_absolute_percentage_error: 10.4466
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#                        mae         rmse      mape
# bear_market_1   244.569075   296.995571  5.706033
# bear_market_2   817.106779  1040.249638  4.402468
# bull_market_1   486.337251   762.300225  6.220275
# bull_market_2  1943.996804  2381.528300  3.827091

# %%
# Get the best hyperparameters for bear market 1
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_percentage_error',
    max_trials=200,
    executions_per_trial=1,
    directory='my_dir',
    project_name='CNNLSTM-3D-REG-bear_market_1',
    overwrite=False
)
best_hps = tuner.get_best_hyperparameters()[0]
best_model = tuner.hypermodel.build(best_hps)
best_model.save('best_model_cnn_lstm_bear_market_1.keras')

# Bear MArket 2
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_percentage_error',
    max_trials=200,
    executions_per_trial=1,
    directory='my_dir',
    project_name='CNNLSTM-3D-REG-bear_market_2',
    overwrite=False
)
best_hps = tuner.get_best_hyperparameters()[0]
best_model = tuner.hypermodel.build(best_hps)
best_model.save('best_model_cnn_lstm_bear_market_2.keras')

# Bull Market 1
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_percentage_error',
    max_trials=200,
    executions_per_trial=1,
    directory='my_dir',
    project_name='CNNLSTM-3D-REG-bull_market_1',
    overwrite=False
)
best_hps = tuner.get_best_hyperparameters()[0]
best_model = tuner.hypermodel.build(best_hps)
best_model.save('best_model_cnn_lstm_bull_market_1.keras')

# Bull Market 2
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_percentage_error',
    max_trials=200,
    executions_per_trial=1,
    directory='my_dir',
    project_name='CNNLSTM-3D-REG-bull_market_2',
    overwrite=False
)
best_hps = tuner.get_best_hyperparameters()[0]
best_model = tuner.hypermodel.build(best_hps)
best_model.save('best_model_cnn_lstm_bull_market_2.keras')
# Out:
# Reloading Tuner from my_dir/CNNLSTM-3D-REG-bear_market_1/tuner0.json
# Reloading Tuner from my_dir/CNNLSTM-3D-REG-bear_market_2/tuner0.json
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Reloading Tuner from my_dir/CNNLSTM-3D-REG-bull_market_1/tuner0.json
# Reloading Tuner from my_dir/CNNLSTM-3D-REG-bull_market_2/tuner0.json
